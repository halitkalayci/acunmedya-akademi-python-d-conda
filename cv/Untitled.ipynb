# %%
import cv2

# %%
img = cv2.imread('dataset/images/1.jpg')
img.shape, img.ndim
# Out:
# ((4608, 2592, 3), 3)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
# epochs => eğitim adeti (baştan tekrar kaç adet eğitim tekrarlansın)
# batch => her epoch başına kaç veri gelecek oranı ( tüm_veri_sayısı / batch => 1955/8 )

# %%
model.train(data="data.yaml", epochs=1, imgsz=640, batch=8)
# Out:
# New https://pypi.org/project/ultralytics/8.3.131 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.130  Python-3.11.11 torch-2.7.0+cpu CPU (AMD Ryzen 9 9950X 16-Core Processor)
# ...

# %%
#Modeli yükleme ve test etme

# %%
model2 = YOLO("runs/detect/train/weights/best.pt")

# %%
img_predict = cv2.imread('dataset/images/514.jpg')
result = model2.predict(source=img_predict, conf=0.5)
# Out:
# 0: 640x640 1 plaka, 31.6ms
# Speed: 2.3ms preprocess, 31.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
result[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6784])
# data: tensor([[1.5350e+03, 1.8917e+03, 2.0272e+03, 2.0101e+03, 6.7836e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (3456, 3456)
# shape: torch.Size([1, 6])
# xywh: tensor([[1781.0928, 1950.8802,  492.2833,  118.4065]])
# xywhn: tensor([[0.5154, 0.5645, 0.1424, 0.0343]])
# xyxy: tensor([[1534.9512, 1891.6770, 2027.2345, 2010.0835]])
# xyxyn: tensor([[0.4441, 0.5474, 0.5866, 0.5816]])

# %%
img2 = img_predict.copy()

# %%
import matplotlib.pyplot as plt

for box in result[0].boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])

    cv2.rectangle(img2, (x1,y1), (x2,y2) , color=(255,0,0), thickness=15)

plt.imshow(img2)
plt.show()

# %%
# Ödev => OCR nedir? Nasıl yapılır araştırılıp uygulamalı bir markdown dosyası oluştur.
